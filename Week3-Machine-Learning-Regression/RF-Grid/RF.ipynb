# %%
#Importing libraies
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#Read dataset
dataset=pd.read_csv("insurance_pre.csv")
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset, drop_first=True)
dataset=dataset.replace({True:1, False:0})
dataset
# Out:
# C:\Users\Mohanraj_Ramasamy\AppData\Local\Temp\ipykernel_18128\3530923882.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   dataset=dataset.replace({True:1, False:0})
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
dependent=dataset[['charges']]
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(independent,dependent,test_size=1/3, random_state=0)

# %%
X_train
# Out:
# array([[-1.53963418,  0.11036616, -0.90788827, -0.98885138, -0.49929923],
#        [ 0.74809711,  0.26412451, -0.0755796 ,  1.01127431,  2.00280702],
#        [ 0.4621307 ,  2.13997636,  1.58903774,  1.01127431, -0.49929923],
#        ...,
#        [ 0.03318108, -0.90443894, -0.90788827,  1.01127431, -0.49929923],
#        [-1.46814257,  0.7869029 , -0.90788827,  1.01127431, -0.49929923],
#        [-0.46726014, -1.96941782, -0.0755796 , -0.98885138, -0.49929923]],
#       shape=(892, 5))

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {'criterion':['friedman_mse', 'poisson', 'squared_error', 'absolute_error'],
'max_features': ['auto','sqrt','log2'],
'n_estimators':[10,100]}
grid=GridSearchCV(RandomForestRegressor(), param_grid, refit = True, verbose=3, n_jobs=-1)
#Fitting the model using grids earch
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# C:\Users\Mohanraj_Ramasamy\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_validation.py:528: FitFailedWarning:
# 40 fits failed out of a total of 120.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Mohanraj_Ramasamy\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Mohanraj_Ramasamy\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "C:\Users\Mohanraj_Ramasamy\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\Mohanraj_Ramasamy\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 35 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Mohanraj_Ramasamy\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Mohanraj_Ramasamy\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "C:\Users\Mohanraj_Ramasamy\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\Mohanraj_Ramasamy\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\Mohanraj_Ramasamy\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_search.py:1108: UserWarning: One or more of the test scores are non-finite: [       nan        nan 0.77624979 0.80073732 0.785387   0.80137465
#         nan        nan 0.7756932  0.80161457 0.78720987 0.79883151
#         nan        nan 0.77921241 0.80214792 0.77228035 0.80129731
#         nan        nan 0.78401709 0.80098154 0.78209945 0.8009001 ]
#   warnings.warn(
# C:\Users\Mohanraj_Ramasamy\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['friedman_mse', 'poisson',
#                                        'squared_error', 'absolute_error'],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [10, 100]},
#              verbose=3)

# %%
# Print best parameter after tunning
re=grid.cv_results_
print("The R_score value for best parameter{}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter{'criterion': 'squared_error', 'max_features': 'sqrt', 'n_estimators': 100}:

# %%
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.000000      0.000000         0.000000    0.000000e+00
# 1        0.000000      0.000000         0.000000    0.000000e+00
# 2        0.026525      0.001073         0.003000    7.979012e-07
# 3        0.240169      0.005797         0.018742    3.370448e-03
# 4        0.027980      0.007449         0.003418    3.785038e-03
# 5        0.225266      0.004655         0.013121    2.093414e-03
# 6        0.000000      0.000000         0.000000    0.000000e+00
# 7        0.000000      0.000000         0.000000    0.000000e+00
# 8        0.026920      0.004742         0.002829    3.750838e-03
# 9        0.277493      0.022382         0.012229    2.285988e-03
# 10       0.031675      0.006901         0.005974    1.978463e-03
# 11       0.266262      0.020805         0.013953    5.729807e-03
# 12       0.001190      0.001496         0.000000    0.000000e+00
# 13       0.000000      0.000000         0.000000    0.000000e+00
# 14       0.026750      0.003045         0.002775    1.956928e-03
# 15       0.238364      0.014001         0.015846    3.471102e-03
# 16       0.028951      0.005125         0.000985    1.574176e-03
# 17       0.237773      0.015318         0.014593    2.720584e-03
# 18       0.002997      0.005995         0.000000    0.000000e+00
# 19       0.001611      0.003221         0.000000    0.000000e+00
# 20       0.075345      0.002524         0.003175    7.278702e-04
# 21       0.591415      0.113163         0.010983    5.466016e-03
# 22       0.061126      0.013956         0.001994    1.870768e-03
# 23       0.639764      0.029939         0.008923    1.296104e-03
#
#    param_criterion param_max_features  param_n_estimators  \
# 0     friedman_mse               auto                  10
# 1     friedman_mse               auto                 100
# 2     friedman_mse               sqrt                  10
# 3     friedman_mse               sqrt                 100
# 4     friedman_mse               log2                  10
# 5     friedman_mse               log2                 100
# 6          poisson               auto                  10
# 7          poisson               auto                 100
# 8          poisson               sqrt                  10
# 9          poisson               sqrt                 100
# 10         poisson               log2                  10
# 11         poisson               log2                 100
# 12   squared_error               auto                  10
# 13   squared_error               auto                 100
# 14   squared_error               sqrt                  10
# 15   squared_error               sqrt                 100
# 16   squared_error               log2                  10
# 17   squared_error               log2                 100
# 18  absolute_error               auto                  10
# 19  absolute_error               auto                 100
# 20  absolute_error               sqrt                  10
# 21  absolute_error               sqrt                 100
# 22  absolute_error               log2                  10
# 23  absolute_error               log2                 100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 1   {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 2   {'criterion': 'friedman_mse', 'max_features': ...           0.777380
# 3   {'criterion': 'friedman_mse', 'max_features': ...           0.807702
# 4   {'criterion': 'friedman_mse', 'max_features': ...           0.800473
# 5   {'criterion': 'friedman_mse', 'max_features': ...           0.809971
# 6   {'criterion': 'poisson', 'max_features': 'auto...                NaN
# 7   {'criterion': 'poisson', 'max_features': 'auto...                NaN
# 8   {'criterion': 'poisson', 'max_features': 'sqrt...           0.771594
# 9   {'criterion': 'poisson', 'max_features': 'sqrt...           0.808837
# 10  {'criterion': 'poisson', 'max_features': 'log2...           0.769779
# 11  {'criterion': 'poisson', 'max_features': 'log2...           0.806494
# 12  {'criterion': 'squared_error', 'max_features':...                NaN
# 13  {'criterion': 'squared_error', 'max_features':...                NaN
# 14  {'criterion': 'squared_error', 'max_features':...           0.796232
# 15  {'criterion': 'squared_error', 'max_features':...           0.807849
# 16  {'criterion': 'squared_error', 'max_features':...           0.774153
# 17  {'criterion': 'squared_error', 'max_features':...           0.807608
# 18  {'criterion': 'absolute_error', 'max_features'...                NaN
# 19  {'criterion': 'absolute_error', 'max_features'...                NaN
# 20  {'criterion': 'absolute_error', 'max_features'...           0.758739
# 21  {'criterion': 'absolute_error', 'max_features'...           0.805815
# 22  {'criterion': 'absolute_error', 'max_features'...           0.788937
# 23  {'criterion': 'absolute_error', 'max_features'...           0.807442
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0                 NaN                NaN                NaN
# 1                 NaN                NaN                NaN
# 2            0.721295           0.825884           0.805610
# 3            0.765199           0.841937           0.826889
# 4            0.760295           0.818319           0.803789
# 5            0.766423           0.831247           0.834822
# 6                 NaN                NaN                NaN
# 7                 NaN                NaN                NaN
# 8            0.740147           0.822875           0.800675
# 9            0.774068           0.835788           0.830986
# 10           0.761970           0.830058           0.810175
# 11           0.769242           0.830276           0.827312
# 12                NaN                NaN                NaN
# 13                NaN                NaN                NaN
# 14           0.752692           0.817542           0.810451
# 15           0.768826           0.839501           0.831054
# 16           0.749613           0.816238           0.782029
# 17           0.768265           0.831295           0.833100
# 18                NaN                NaN                NaN
# 19                NaN                NaN                NaN
# 20           0.752361           0.842763           0.804412
# 21           0.775227           0.842590           0.818671
# 22           0.762932           0.822531           0.787667
# 23           0.771764           0.835247           0.826395
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0                 NaN              NaN             NaN               17
# 1                 NaN              NaN             NaN               17
# 2            0.751079         0.776250        0.037364               14
# 3            0.761960         0.800737        0.032238                7
# 4            0.744060         0.785387        0.028243               10
# 5            0.764411         0.801375        0.030571                3
# 6                 NaN              NaN             NaN               17
# 7                 NaN              NaN             NaN               17
# 8            0.743174         0.775693        0.032212               15
# 9            0.758393         0.801615        0.030691                2
# 10           0.764068         0.787210        0.027712                9
# 11           0.760834         0.798832        0.028907                8
# 12                NaN              NaN             NaN               17
# 13                NaN              NaN             NaN               17
# 14           0.719146         0.779212        0.037539               13
# 15           0.763510         0.802148        0.031198                1
# 16           0.739369         0.772280        0.026936               16
# 17           0.766220         0.801297        0.029232                4
# 18                NaN              NaN             NaN               17
# 19                NaN              NaN             NaN               17
# 20           0.761810         0.784017        0.034645               11
# 21           0.762605         0.800982        0.028995                5
# 22           0.748430         0.782099        0.025352               12
# 23           0.763652         0.800900        0.028667                6

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children=float(input("Children:"))
sex_male_input=int(input("sex male 0 or 1:"))
smoke_yes_input=int(input("smoke yes 0 or 1:"))

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children,sex_male_input,smoke_yes_input]])
print("Future Prediction={}".format(Future_Prediction))
# Out:
# Future Prediction=[14676.7674633]
