# %%
#Importing libraies
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#Read dataset
dataset=pd.read_csv("insurance_pre.csv")
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset, drop_first=True)
dataset=dataset.replace({True:1, False:0})
dataset
# Out:
# C:\Users\Mohanraj_Ramasamy\AppData\Local\Temp\ipykernel_36612\3530923882.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   dataset=dataset.replace({True:1, False:0})
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
dependent=dataset[['charges']]
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
param_grid = {'kernel':['sigmoid'], 'C':[10,100,1000,2000,3000], 'gamma':['auto','scale']}
grid=GridSearchCV(SVR(), param_grid, refit = True, verbose=3, n_jobs=-1)
#Fitting the model using grids earch
grid.fit(independent, dependent)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# C:\Users\Mohanraj_Ramasamy\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [10, 100, 1000, 2000, 3000],
#                          'gamma': ['auto', 'scale'], 'kernel': ['sigmoid']},
#              verbose=3)

# %%
# Print best parameter after tunning
re=grid.cv_results_
print("The R_score value for best parameter{}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter{'C': 10, 'gamma': 'auto', 'kernel': 'sigmoid'}:

# %%
table=pd.DataFrame.from_dict(re)
table
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0       0.243051      0.045797         0.035298        0.014587       10
# 1       0.339403      0.079305         0.073615        0.027790       10
# 2       0.186327      0.043172         0.026219        0.012185      100
# 3       0.377743      0.077049         0.058690        0.008057      100
# 4       0.173900      0.048618         0.029313        0.011363     1000
# 5       0.303796      0.045845         0.055395        0.003862     1000
# 6       0.140445      0.023352         0.023850        0.003381     2000
# 7       0.283227      0.025668         0.059929        0.010153     2000
# 8       0.146955      0.020637         0.026230        0.002996     3000
# 9       0.211152      0.012754         0.041683        0.003541     3000
#
#   param_gamma param_kernel                                             params  \
# 0        auto      sigmoid    {'C': 10, 'gamma': 'auto', 'kernel': 'sigmoid'}
# 1       scale      sigmoid   {'C': 10, 'gamma': 'scale', 'kernel': 'sigmoid'}
# 2        auto      sigmoid   {'C': 100, 'gamma': 'auto', 'kernel': 'sigmoid'}
# 3       scale      sigmoid  {'C': 100, 'gamma': 'scale', 'kernel': 'sigmoid'}
# 4        auto      sigmoid  {'C': 1000, 'gamma': 'auto', 'kernel': 'sigmoid'}
# 5       scale      sigmoid  {'C': 1000, 'gamma': 'scale', 'kernel': 'sigmo...
# 6        auto      sigmoid  {'C': 2000, 'gamma': 'auto', 'kernel': 'sigmoid'}
# 7       scale      sigmoid  {'C': 2000, 'gamma': 'scale', 'kernel': 'sigmo...
# 8        auto      sigmoid  {'C': 3000, 'gamma': 'auto', 'kernel': 'sigmoid'}
# 9       scale      sigmoid  {'C': 3000, 'gamma': 'scale', 'kernel': 'sigmo...
#
#    split0_test_score  split1_test_score  split2_test_score  split3_test_score  \
# 0          -0.115328          -0.113567          -0.081608          -0.106067
# 1          -0.116743          -0.119312          -0.085214          -0.108210
# 2          -0.115328          -0.113567          -0.081608          -0.106067
# 3          -0.142455          -0.160831          -0.117544          -0.137984
# 4          -0.115328          -0.113567          -0.081608          -0.106067
# 5          -2.043140          -2.686121          -2.194563          -2.210858
# 6          -0.115328          -0.113567          -0.081608          -0.106067
# 7          -7.209317          -9.282940          -7.776578          -7.745074
# 8          -0.115328          -0.113567          -0.081608          -0.106067
# 9         -15.561853         -20.498908         -17.095474         -16.750877
#
#    split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0          -0.107195        -0.104753        0.012107                1
# 1          -0.108716        -0.107639        0.012029                6
# 2          -0.107195        -0.104753        0.012107                1
# 3          -0.130402        -0.137843        0.014263                7
# 4          -0.107195        -0.104753        0.012107                1
# 5          -1.942521        -2.215441        0.255409                8
# 6          -0.107195        -0.104753        0.012107                1
# 7          -6.891719        -7.781126        0.821557                9
# 8          -0.107195        -0.104753        0.012107                1
# 9         -15.012168       -16.983856        1.914783               10

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children=float(input("Children:"))
sex_male_input=int(input("sex male 0 or 1:"))
smoke_yes_input=int(input("smoke yes 0 or 1:"))

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children,sex_male_input,smoke_yes_input]])
print("Future Prediction={}".format(Future_Prediction))
# Out:
# Future Prediction=[9382.033]
# C:\Users\Mohanraj_Ramasamy\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
